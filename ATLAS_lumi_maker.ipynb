# %%
import pandas as pd

# %%
lumi_data = pd.read_csv("./RUN1-RUN2_ATLAS_lum.csv")

# %%
lumi_data
# Out:
#           Timestamp          ATLAS
# 0     1259417511146       0.000000
# 1     1259456213472       0.000000
# 2     1259479840222       0.000000
# 3     1259557022577       0.000000
# 4     1259625221614       0.000000
# 5     1259790539481       0.000000
# 6     1259812257523       0.000000
# 7     1259844434238       0.000000
# 8     1259850580752       0.000000
# 9     1259857311459       0.000000
# 10    1259866223572       0.000000
# 11    1259911907562       0.000000
# 12    1259949732070       0.000000
# 13    1260001076780       0.000000
# 14    1260050356705       0.000000
# 15    1260128645407       0.000000
# 16    1260228974389       0.000000
# 17    1260257730754       0.000000
# 18    1260380637672       0.000000
# 19    1260416108352       0.000000
# 20    1260455317666       0.000000
# 21    1260510850603       0.000000
# 22    1260527247313       0.000000
# 23    1260603793115       0.000000
# 24    1260622219823       0.000000
# 25    1260643813014       0.000000
# ...

# %%
lumi_data.head()
# Out:
#        Timestamp  ATLAS
# 0  1259417511146    0.0
# 1  1259456213472    0.0
# 2  1259479840222    0.0
# 3  1259557022577    0.0
# 4  1259625221614    0.0

# %%
lumi_data.tail()
# Out:
#           Timestamp          ATLAS
# 6131  1543057459481  187579.165374
# 6132  1543096077797  187579.165374
# 6133  1543133970103  187579.165374
# 6134  1543178560829  187579.165374
# 6135  1543216389642  187579.165374

# %%
lumi_data.dtypes
# Out:
# Timestamp      int64
# ATLAS        float64
# dtype: object

# %%
lumi_data['ATLAS'].describe()
# Out:
# count      6136.000000
# mean      54053.770281
# std       53488.725240
# min           0.000000
# 25%       12877.544459
# 50%       29347.494694
# 75%       78153.531719
# max      187579.165374
# Name: ATLAS, dtype: float64

# %%
lumi_data = lumi_data.drop(["Date Time", "ALICE", "CMS", "LHCb", "Fill Number"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-cbda54b6c71c> in <module>()
# ----> 1 lumi_data = lumi_data.drop(["Date Time", "ALICE", "CMS", "LHCb", "Fill Number"], axis=1)
#
# /Users/emintagiev/Documents/Учёба/DMIA_2018/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# /Users/emintagiev/Documents/Учёба/DMIA_2018/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# ...

# %%
lumi_data.tail()
# Out:
#           Timestamp          ATLAS
# 6131  1543057459481  187579.165374
# 6132  1543096077797  187579.165374
# 6133  1543133970103  187579.165374
# 6134  1543178560829  187579.165374
# 6135  1543216389642  187579.165374

# %%
lumi_data.rename(columns={"Timestamp": "Unix time"})
# Out:
#           Unix time          ATLAS
# 0     1259417511146       0.000000
# 1     1259456213472       0.000000
# 2     1259479840222       0.000000
# 3     1259557022577       0.000000
# 4     1259625221614       0.000000
# 5     1259790539481       0.000000
# 6     1259812257523       0.000000
# 7     1259844434238       0.000000
# 8     1259850580752       0.000000
# 9     1259857311459       0.000000
# 10    1259866223572       0.000000
# 11    1259911907562       0.000000
# 12    1259949732070       0.000000
# 13    1260001076780       0.000000
# 14    1260050356705       0.000000
# 15    1260128645407       0.000000
# 16    1260228974389       0.000000
# 17    1260257730754       0.000000
# 18    1260380637672       0.000000
# 19    1260416108352       0.000000
# 20    1260455317666       0.000000
# 21    1260510850603       0.000000
# 22    1260527247313       0.000000
# 23    1260603793115       0.000000
# 24    1260622219823       0.000000
# 25    1260643813014       0.000000
# ...

# %%
lumi_data.to_csv("RUN1-RUN2_ATLAS_lum.csv", index=False, encoding='utf8')
